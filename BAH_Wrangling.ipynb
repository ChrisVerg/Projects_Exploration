# %%
import pandas as pd

# %%
# Import datasets of 2023 BAH rates with and without dependents

# %%
BAHwith = pd.read_csv('BAHWithDep.csv')

# %%
BAHwithout = pd.read_csv('BAHWithOutDep.csv')

# %%
# Set no max rows and columns to view data
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
BAHwith
# In each step the df name will be BAHwith#. # represents the corresponding number of the step below

# 1Rename the column titles
# 2Keep only E1 to E7
# 3Split the city and State
# 4Combine the Datasets
# 5Keep Only North Carolina Data
# Out:
#     2023 BAH Rates - WITH DEPENDENTS                     Unnamed: 1  \
# 0                                MHA                       MHA_NAME
# 1                              AK400                  KETCHIKAN, AK
# 2                              AK401                      SITKA, AK
# 3                              AK402                     JUNEAU, AK
# 4                              AK403              KODIAK ISLAND, AK
# 5                              AK404                  ANCHORAGE, AK
# 6                              AK405                  FAIRBANKS, AK
# 7                              AL001    ANNISTON/FORT MCCLELLAN, AL
# 8                              AL002                FORT RUCKER, AL
# 9                              AL003                 HUNTSVILLE, AL
# 10                             AL004                     MOBILE, AL
# 11                             AL005                 MONTGOMERY, AL
# 12                             AL006                     AUBURN, AL
# ...

# %%
BAHwith.columns
# Out:
# Index(['2023 BAH Rates - WITH DEPENDENTS', 'Unnamed: 1', 'Unnamed: 2',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24',
#        'Unnamed: 25'],
#       dtype='object')

# %%
# Rename the columns that are going to be used
BAHwith1 = BAHwith.rename(columns={'Unnamed: 1':'City,State', 'Unnamed: 2':'E1_with_Dep','Unnamed: 3':'E2_with_Dep', 'Unnamed: 4':'E3_with_Dep', 'Unnamed: 5':'E4_with_Dep', 'Unnamed: 6':'E5_with_Dep', 'Unnamed: 7':'E6_with_Dep','Unnamed: 8':'E7_with_Dep'})
BAHwith1.columns
# Out:
# Index(['2023 BAH Rates - WITH DEPENDENTS', 'City,State', 'E1_with_Dep',
#        'E2_with_Dep', 'E3_with_Dep', 'E4_with_Dep', 'E5_with_Dep',
#        'E6_with_Dep', 'E7_with_Dep', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25'],
#       dtype='object')

# %%
# Subset the data keeping up the the grade of E7 and the City/State
BAHwith2 = BAHwith1[['City,State', 'E1_with_Dep','E2_with_Dep', 'E3_with_Dep', 'E4_with_Dep', 'E5_with_Dep','E6_with_Dep', 'E7_with_Dep']]
BAHwith2
# Out:
#                         City,State E1_with_Dep E2_with_Dep E3_with_Dep  \
# 0                         MHA_NAME         E01         E02         E03
# 1                    KETCHIKAN, AK        2034        2034        2034
# 2                        SITKA, AK        1884        1884        1884
# 3                       JUNEAU, AK        2088        2088        2088
# 4                KODIAK ISLAND, AK        2118        2118        2118
# 5                    ANCHORAGE, AK        1995        1995        1995
# 6                    FAIRBANKS, AK        1833        1833        1833
# 7      ANNISTON/FORT MCCLELLAN, AL        1017        1017        1017
# 8                  FORT RUCKER, AL        1239        1239        1239
# 9                   HUNTSVILLE, AL        1563        1563        1563
# 10                      MOBILE, AL        1587        1587        1587
# 11                  MONTGOMERY, AL        1356        1356        1356
# ...

# %%
# Split the the City and State into their own Columns
BAHwith3 = BAHwith2['City,State'].str.split(',', expand=True)
BAHwith3
# Out:
#                              0               1     2
# 0                     MHA_NAME            None  None
# 1                    KETCHIKAN              AK  None
# 2                        SITKA              AK  None
# 3                       JUNEAU              AK  None
# 4                KODIAK ISLAND              AK  None
# 5                    ANCHORAGE              AK  None
# 6                    FAIRBANKS              AK  None
# 7      ANNISTON/FORT MCCLELLAN              AL  None
# 8                  FORT RUCKER              AL  None
# 9                   HUNTSVILLE              AL  None
# 10                      MOBILE              AL  None
# 11                  MONTGOMERY              AL  None
# 12                      AUBURN              AL  None
# 13                  BIRMINGHAM              AL  None
# 14                 LITTLE ROCK              AR  None
# 15     FORT CHAFFEE/FORT SMITH              AR  None
# 16                FAYETTEVILLE              AR  None
# ...

# %%
# Add column names to the newly split columns
BAHwith3.rename(columns={0:'City', 1: 'State'}, inplace=True)

# %%
BAHwith3
# Out:
#                           City           State     2
# 0                     MHA_NAME            None  None
# 1                    KETCHIKAN              AK  None
# 2                        SITKA              AK  None
# 3                       JUNEAU              AK  None
# 4                KODIAK ISLAND              AK  None
# 5                    ANCHORAGE              AK  None
# 6                    FAIRBANKS              AK  None
# 7      ANNISTON/FORT MCCLELLAN              AL  None
# 8                  FORT RUCKER              AL  None
# 9                   HUNTSVILLE              AL  None
# 10                      MOBILE              AL  None
# 11                  MONTGOMERY              AL  None
# 12                      AUBURN              AL  None
# 13                  BIRMINGHAM              AL  None
# 14                 LITTLE ROCK              AR  None
# 15     FORT CHAFFEE/FORT SMITH              AR  None
# 16                FAYETTEVILLE              AR  None
# ...

# %%
# Merge the two data frames
BAHwith4 = pd.concat([BAHwith3, BAHwith2], axis = 1)

# %%
BAHwith4.columns
# Out:
# Index([       'City',       'State',             2,  'City,State',
#        'E1_with_Dep', 'E2_with_Dep', 'E3_with_Dep', 'E4_with_Dep',
#        'E5_with_Dep', 'E6_with_Dep', 'E7_with_Dep'],
#       dtype='object')

# %%
# filter out all other state data except North Carolina
BAHwith_NConly = BAHwith4[167:178]
BAHwith_NConly
# Out:
#                         City State     2                   City,State  \
# 167              OUTER BANKS    NC  None              OUTER BANKS, NC
# 168  MOREHEAD/CHERRY PT MCAS    NC  None  MOREHEAD/CHERRY PT MCAS, NC
# 169             CAMP LEJEUNE    NC  None             CAMP LEJEUNE, NC
# 170                CHARLOTTE    NC  None                CHARLOTTE, NC
# 171       DURHAM/CHAPEL HILL    NC  None       DURHAM/CHAPEL HILL, NC
# 172           ELIZABETH CITY    NC  None           ELIZABETH CITY, NC
# 173          FORT BRAGG/POPE    NC  None          FORT BRAGG/POPE, NC
# 174      SEYMOUR JOHNSON AFB    NC  None      SEYMOUR JOHNSON AFB, NC
# 175               GREENSBORO    NC  None               GREENSBORO, NC
# 176                  RALEIGH    NC  None                  RALEIGH, NC
# 177               WILMINGTON    NC  None               WILMINGTON, NC
#
#     E1_with_Dep E2_with_Dep E3_with_Dep E4_with_Dep E5_with_Dep E6_with_Dep  \
# ...

# %%
# Drop columns '2' and 'City,State'
# "2" is causing an error message
BAHwith_NConly = BAHwith_NConly.drop(['City,State'], axis = 1)
BAHwith_NConly
# Out:
#                         City State     2 E1_with_Dep E2_with_Dep E3_with_Dep  \
# 167              OUTER BANKS    NC  None        1944        1944        1944
# 168  MOREHEAD/CHERRY PT MCAS    NC  None        1659        1659        1659
# 169             CAMP LEJEUNE    NC  None        1335        1335        1335
# 170                CHARLOTTE    NC  None        2013        2013        2013
# 171       DURHAM/CHAPEL HILL    NC  None        1815        1815        1815
# 172           ELIZABETH CITY    NC  None        1779        1779        1779
# 173          FORT BRAGG/POPE    NC  None        1530        1530        1530
# 174      SEYMOUR JOHNSON AFB    NC  None        1230        1230        1230
# 175               GREENSBORO    NC  None        1539        1539        1539
# 176                  RALEIGH    NC  None        1938        1938        1938
# 177               WILMINGTON    NC  None        1779        1779        1779
#
# ...

# %%
# Drop columns '2'
BAHwith_NConly.rename(columns={2:'delete'}, inplace=True)
BAHwith_NConly = BAHwith_NConly.drop(['delete'], axis = 1)

# %%
BAHwith5 = BAHwith_NConly

# %%
# This is the clean data for E1 through E7 in North Carolina with dependents
BAHwith5
# Out:
#                         City State E1_with_Dep E2_with_Dep E3_with_Dep  \
# 167              OUTER BANKS    NC        1944        1944        1944
# 168  MOREHEAD/CHERRY PT MCAS    NC        1659        1659        1659
# 169             CAMP LEJEUNE    NC        1335        1335        1335
# 170                CHARLOTTE    NC        2013        2013        2013
# 171       DURHAM/CHAPEL HILL    NC        1815        1815        1815
# 172           ELIZABETH CITY    NC        1779        1779        1779
# 173          FORT BRAGG/POPE    NC        1530        1530        1530
# 174      SEYMOUR JOHNSON AFB    NC        1230        1230        1230
# 175               GREENSBORO    NC        1539        1539        1539
# 176                  RALEIGH    NC        1938        1938        1938
# 177               WILMINGTON    NC        1779        1779        1779
#
#     E4_with_Dep E5_with_Dep E6_with_Dep E7_with_Dep
# 167        1944        1947        2025        2067
# ...

# %% [markdown]
# ## Now complete the same tasks for the data without dependents

# %%
BAHwithout
# In each step the df name will be BAHwith#. # represents the corresponding number of the step below

# 1Rename the column titles
# 2Keep only E1 to E7
# 3Drop all data except for North Carolina Index 167/178
# Out:
#     2023 BAH Rates - WITHOUT DEPENDENTS                     Unnamed: 1  \
# 0                                   MHA                       MHA_NAME
# 1                                 AK400                  KETCHIKAN, AK
# 2                                 AK401                      SITKA, AK
# 3                                 AK402                     JUNEAU, AK
# 4                                 AK403              KODIAK ISLAND, AK
# 5                                 AK404                  ANCHORAGE, AK
# 6                                 AK405                  FAIRBANKS, AK
# 7                                 AL001    ANNISTON/FORT MCCLELLAN, AL
# 8                                 AL002                FORT RUCKER, AL
# 9                                 AL003                 HUNTSVILLE, AL
# 10                                AL004                     MOBILE, AL
# 11                                AL005                 MONTGOMERY, AL
# ...

# %%
# Rename the columns that need to be kept
BAHwithout1 = BAHwithout.rename(columns={'Unnamed: 1':'City,State', 'Unnamed: 2':'E1_without_Dep','Unnamed: 3':'E2_without_Dep', 'Unnamed: 4':'E3_without_Dep', 'Unnamed: 5':'E4_without_Dep', 'Unnamed: 6':'E5_without_Dep', 'Unnamed: 7':'E6_without_Dep','Unnamed: 8':'E7_without_Dep'})
BAHwithout1.columns
# Out:
# Index(['2023 BAH Rates - WITHOUT DEPENDENTS', 'City,State', 'E1_without_Dep',
#        'E2_without_Dep', 'E3_without_Dep', 'E4_without_Dep', 'E5_without_Dep',
#        'E6_without_Dep', 'E7_without_Dep', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14',
#        'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22',
#        'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26',
#        'Unnamed: 27'],
#       dtype='object')

# %%
# Subset the data keeping up the the grade of E7
BAHwithout2 = BAHwithout1[['E1_without_Dep','E2_without_Dep', 'E3_without_Dep', 'E4_without_Dep', 'E5_without_Dep','E6_without_Dep', 'E7_without_Dep']]
BAHwith2
# Out:
#                         City,State E1_with_Dep E2_with_Dep E3_with_Dep  \
# 0                         MHA_NAME         E01         E02         E03
# 1                    KETCHIKAN, AK        2034        2034        2034
# 2                        SITKA, AK        1884        1884        1884
# 3                       JUNEAU, AK        2088        2088        2088
# 4                KODIAK ISLAND, AK        2118        2118        2118
# 5                    ANCHORAGE, AK        1995        1995        1995
# 6                    FAIRBANKS, AK        1833        1833        1833
# 7      ANNISTON/FORT MCCLELLAN, AL        1017        1017        1017
# 8                  FORT RUCKER, AL        1239        1239        1239
# 9                   HUNTSVILLE, AL        1563        1563        1563
# 10                      MOBILE, AL        1587        1587        1587
# 11                  MONTGOMERY, AL        1356        1356        1356
# ...

# %%
# 3Drop all data except for North Carolina Index 167/178
BAHwithout3 = BAHwithout2[167:178]
BAHwithout3
# Out:
#     E1_without_Dep E2_without_Dep E3_without_Dep E4_without_Dep  \
# 167           1503           1503           1503           1503
# 168           1521           1521           1521           1521
# 169           1101           1101           1101           1101
# 170           1566           1566           1566           1566
# 171           1518           1518           1518           1518
# 172           1539           1539           1539           1539
# 173           1230           1230           1230           1230
# 174           1092           1092           1092           1092
# 175           1155           1155           1155           1155
# 176           1530           1530           1530           1530
# 177           1392           1392           1392           1392
#
#     E5_without_Dep E6_without_Dep E7_without_Dep
# 167           1785           1944           1965
# 168           1602           1662           1683
# ...

# %%
BAHrates= pd.merge(BAHwith5, BAHwithout3, left_index = True, right_index = True)

# %%
BAHrates.to_csv('C:/Users/chris/Desktop/GitHub/BAHrates.csv')
